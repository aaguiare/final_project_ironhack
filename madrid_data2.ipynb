# %%
import pandas as pd
import numpy as np

# %%
puntos_limpios_moviles = pd.read_csv('./data/Madrid/PuntosLimpiosMoviles.csv', sep = ';')
puntos_limpios_moviles
# Out:
#               TIPO_DATO                                 DIRECCION_COMPLETA  \
# 0    Punto Limpio Móvil                                 Calle Arrieta, 15
# 1    Punto Limpio Móvil                                Calle Barquillo, 4
# 2    Punto Limpio Móvil                                 Plaza Cebada, 5-7
# 3    Punto Limpio Móvil                             Calle Conde Duque, 30
# 4    Punto Limpio Móvil  Glorieta Embajadores, 10 esquina calle Embajad...
# ..                  ...                                                ...
# 346  Punto Limpio Móvil                                    Plaza Navío, 1
# 347  Punto Limpio Móvil                          Calle Playa de Zarauz, 1
# 348  Punto Limpio Móvil                            Calle Pradoluengo, 243
# 349  Punto Limpio Móvil  calle Ribera del Sena, 21 esquina con Estrasbu...
# 350  Punto Limpio Móvil                                   Calle Rioja, 27
#
#                                     DIRECCION AUXILIAR CLASE_VIAL  \
# ...

# %%
ropa = pd.read_csv('./data/Madrid/ContenedoresRopa.csv', sep = ';')

ropa
# Out:
#                TIPO_DATO  LOTE  COD_DISTRITO DISTRITO  COD_BARRIO      BARRIO  \
# 0     Contenedor de Ropa     1             1   Centro          11     Palacio
# 1     Contenedor de Ropa     1             1   Centro          11     Palacio
# 2     Contenedor de Ropa     1             1   Centro          11     Palacio
# 3     Contenedor de Ropa     1             1   Centro          11     Palacio
# 4     Contenedor de Ropa     1             1   Centro          11     Palacio
# ...                  ...   ...           ...      ...         ...         ...
# 1333  Contenedor de ropa     2            21  Barajas         215  Corralejos
# 1334  Contenedor de ropa     2            21  Barajas         215  Corralejos
# 1335  Contenedor de ropa     2            21  Barajas         215  Corralejos
# 1336  Contenedor de ropa     2            21  Barajas         215  Corralejos
# 1337  Contenedor de Ropa     2            21  Barajas         215  Corralejos
#
# ...

# %%
puntos_limpios_fijos = pd.read_csv('./data/Madrid/200284-0-puntos-limpios-fijos.csv', sep = ';', encoding='ISO-8859-1')
puntos_limpios_fijos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PK                   16 non-null     int64
#  1   NOMBRE               16 non-null     object
#  2   DESCRIPCION-ENTIDAD  0 non-null      float64
#  3   HORARIO              16 non-null     object
#  4   EQUIPAMIENTO         0 non-null      float64
#  5   TRANSPORTE           16 non-null     object
#  6   DESCRIPCION          16 non-null     object
#  7   ACCESIBILIDAD        16 non-null     int64
#  8   CONTENT-URL          16 non-null     object
#  9   NOMBRE-VIA           16 non-null     object
#  10  CLASE-VIAL           16 non-null     object
#  11  TIPO-NUM             16 non-null     object
#  12  NUM                  16 non-null     int64
#  13  PLANTA               0 non-null      float64
#  14  PUERTA               0 non-null      float64
# ...

# %%
aceite = pd.read_csv('./data/Madrid/RecogidaContenedoresAceiteUsado.csv', sep = ';')
aceite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TIPO  SITUADO       122 non-null    object
#  1   DISTRITO            122 non-null    object
#  2   DIRECCION COMPLETA  122 non-null    object
#  3   CLASE_VIAL          122 non-null    object
#  4   NOMBRE_VIAL         122 non-null    object
#  5   NUM                 121 non-null    object
#  6   DIRECCION AUX       5 non-null      object
#  7   DEPENDENCIA         74 non-null     object
#  8   X                   119 non-null    object
#  9   Y                   119 non-null    object
#  10  LATITUD             122 non-null    object
#  11  LONGITUD            122 non-null    object
# dtypes: object(12)
# memory usage: 11.6+ KB

# %%
contenedores_varios = pd.read_csv('./data/Madrid/Contenedores_varios.csv', sep = ';')
contenedores_varios['Tipo Contenedor'].unique()
# Out:
# array(['RESTO', 'PAPEL-CARTON', 'ENVASES', 'ORGANICA', 'VIDRIO'],
#       dtype=object)

# %%
vidrio = contenedores_varios[contenedores_varios['Tipo Contenedor'] == 'VIDRIO']
vidrio
# Out:
#        Código Interno del Situad Tipo Contenedor     Modelo  \
# 167                       179223          VIDRIO      IG_11
# 169                       179148          VIDRIO      IG_11
# 172                       179323          VIDRIO      IG_11
# 174                       179220          VIDRIO      IG_11
# 180                       178958          VIDRIO      IG_11
# ...                          ...             ...        ...
# 43629                     401533          VIDRIO  IG_21_226
# 43631                     401536          VIDRIO  IG_21_227
# 43633                     401538          VIDRIO  IG_21_228
# 43634                     401540          VIDRIO  IG_21_229
# 43636                     405504          VIDRIO  IG_21_230
#
#             Descripcion Modelo  Cantidad  Lote     Distrito  Barrio Tipo Vía  \
# 167          V 3000 CAMPANA PE         1     3  CARABANCHEL     NaN    CALLE
# 169          V 3000 CAMPANA PE         1     3  CARABANCHEL     NaN    CALLE
# ...

# %%
papel = contenedores_varios[contenedores_varios['Tipo Contenedor'] == 'PAPEL-CARTON']
papel
# Out:
#        Código Interno del Situad Tipo Contenedor     Modelo  \
# 6                         182476    PAPEL-CARTON      IG_17
# 7                         182477    PAPEL-CARTON      IG_12
# 8                         183366    PAPEL-CARTON      IG_13
# 9                         183367    PAPEL-CARTON      IG_13
# 10                        183370    PAPEL-CARTON      IG_11
# ...                          ...             ...        ...
# 43626                     401531    PAPEL-CARTON  IG_21_225
# 43628                     401533    PAPEL-CARTON  IG_21_226
# 43630                     401536    PAPEL-CARTON  IG_21_227
# 43632                     401538    PAPEL-CARTON  IG_21_228
# 43635                     405504    PAPEL-CARTON  IG_21_230
#
#              Descripcion Modelo  Cantidad  Lote            Distrito  Barrio  \
# 6            PC 3000 CAMPANA PE         1     3          VILLAVERDE     NaN
# 7            PC 3000 CAMPANA PE         1     3               USERA     NaN
# ...

# %%
resto = contenedores_varios[contenedores_varios['Tipo Contenedor'] == 'RESTO']
resto
# Out:
#        Código Interno del Situad Tipo Contenedor     Modelo  \
# 0                         181193           RESTO      CL_18
# 1                         181843           RESTO      CL_18
# 2                         178948           RESTO      CL_18
# 3                         181864           RESTO      CL_18
# 4                         181872           RESTO      CL_13
# ...                          ...             ...        ...
# 37640                     166739           RESTO  CT_21_067
# 37641                     166739           RESTO  CT_21_067
# 37644                     184836           RESTO  CT_21_068
# 37648                     921070           RESTO  CT_21_070
# 37649                     921070           RESTO  CT_21_070
#
#       Descripcion Modelo  Cantidad  Lote            Distrito  Barrio Tipo Vía  \
# 0            Res 3200 CL         1     3   VILLA DE VALLECAS     NaN    CALLE
# 1            Res 3200 CL         1     3   VILLA DE VALLECAS     NaN    CALLE
# ...

# %%
envases = contenedores_varios[contenedores_varios['Tipo Contenedor'] == 'ENVASES']
envases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8936 entries, 61 to 37646
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código Interno del Situad  8936 non-null   int64
#  1   Tipo Contenedor            8936 non-null   object
#  2   Modelo                     8936 non-null   object
#  3   Descripcion Modelo         8936 non-null   object
#  4   Cantidad                   8936 non-null   int64
#  5   Lote                       8936 non-null   int64
#  6   Distrito                   8936 non-null   object
#  7   Barrio                     0 non-null      float64
#  8   Tipo Vía                   8936 non-null   object
#  9   Nombre                     8936 non-null   object
#  10  Número                     8923 non-null   float64
#  11  COORDENADA X               8936 non-null   object
#  12  COORDENADA Y               8936 non-null   object
# ...

# %%
organica = contenedores_varios[contenedores_varios['Tipo Contenedor'] == 'ORGANICA']
organica
# Out:
#        Código Interno del Situad Tipo Contenedor     Modelo  \
# 62                        183911        ORGANICA      CL_17
# 201                       179046        ORGANICA      CL_13
# 206                       179055        ORGANICA      CL_13
# 220                       179285        ORGANICA      CL_13
# 225                       179283        ORGANICA      CL_13
# ...                          ...             ...        ...
# 37631                     166737        ORGANICA  CT_21_065
# 37635                     166738        ORGANICA  CT_21_066
# 37639                     166739        ORGANICA  CT_21_067
# 37643                     184836        ORGANICA  CT_21_068
# 37647                     921070        ORGANICA  CT_21_070
#
#       Descripcion Modelo  Cantidad  Lote            Distrito  Barrio Tipo Vía  \
# 62             O 3200 CL         1     3          VILLAVERDE     NaN    CALLE
# 201            O 3200 CL         1     3  PUENTE DE VALLECAS     NaN  AVENIDA
# ...

# %%
pilas = pd.read_csv('./data/Madrid/Marquesinas_contenedores_pilas_2022.csv', sep = ';')
pilas
# Out:
#       Parada  nodo Inter Urbano         TIPO MOBILIARIO (ACTUAL)  \
# 0         23             6341.0       MARQUESINA MOD XXI 5-M STD
# 1         24                NaN       MARQUESINA MOD XXI 4-M STD
# 2         31                NaN       MARQUESINA MOD XXI 5-M STD
# 3         53                NaN       MARQUESINA MOD XXI 5-M STD
# 4         70                NaN       MARQUESINA MOD XXI 5-M STD
# ...      ...                ...                              ...
# 1480   11278            11278.0       MARQUESINA MOD XXI 5-M STD
# 1481   11760            11760.0       MARQUESINA MOD XXI 5-M STD
# 1482   12697            12697.0  MARQUESINA MOD XXI 4-M REDUCIDA
# 1483   15525            15525.0       MARQUESINA MOD XXI 5-M STD
# 1484   15695            15695.0       MARQUESINA MOD XXI 5-M STD
#
#               DISTRITO         DIRECCIÓN   VIAL  Nº  \
# 0     MONCLOA-ARAVACA   PUERTA DE HIERRO     AV
# 1           HORTALEZA     MAR DE CRISTAL    GTA
# ...
